# %%
from bs4 import BeautifulSoup

# %%
import requests
import pandas as pd
import numpy as np

# %%
soup = pd.read_html("table_9.html")
soup1 = pd.read_html('table_62.html')
soup2 = pd.read_html('table_12.html')

# %%
soup
# Out:
# [                                         0   \
#  0                                       NaN
#  1                                         Â
#  2                                         Â
#  3                 Revenues ($ millions) (2)
#  4                   Petroleum and chemicals
#  5                       Metals and minerals
#  6                           Forest products
#  7                                      Coal
#  8                     Grain and fertilizers
#  9                                Intermodal
#  10                               Automotive
#  11                   Total freight revenues
#  12                           Other revenues
#  13                           Total revenues
#  14  Revenue ton miles (RTMs) (millions) (3)
#  15                  Petroleum and chemicals
#  16                      Metals and minerals
#  17                          Forest products
#  18                                     Coal
#  19                    Grain and fertilizers
# ...

# %%
soup1
# Out:
# [                                0                                1   \
#  0                              NaN                              NaN
#  1                              NaN                              NaN
#  2                      In millions                      In millions
#  3             Debt obligations (1)             Debt obligations (1)
#  4     Interest on debt obligations     Interest on debt obligations
#  5        Finance lease obligations        Finance lease obligations
#  6  Operating lease obligations (2)  Operating lease obligations (2)
#  7         Purchase obligations (3)         Purchase obligations (3)
#  8  Other long-term liabilities (4)  Other long-term liabilities (4)
#  9    Total contractual obligations    Total contractual obligations
#
#                                  2       3        4      5   6   7   8   \
#  0                              NaN     NaN      NaN    NaN NaN NaN NaN
# ...

# %%
soup2
# Out:
# [                                                   0   \
#  0                                                 NaN
#  1                                                   Â
#  2                                         In millions
#  3           Net cash provided by operating activities
#  4               Net cash used in investing activities
#  5       Net cash provided before financing activities
#  6   Adjustment: Cash income taxes for merger trans...
#  7                                                 NaN
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#  13                                                NaN
#  14                                     Free cash flow
#
#                                                     1   \
# ...
