# %%
pip install kaggle
# Out:
# ...
#      ---------------------------------------- 0.0/82.7 kB ? eta -:--:--
#      -------------- ----------------------- 30.7/82.7 kB 660.6 kB/s eta 0:00:01
#      ---------------------------------------  81.9/82.7 kB 1.2 MB/s eta 0:00:01
#      -------------------------------------- 82.7/82.7 kB 928.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105802 sha256=a1fb477024b1f6c7f404389d0f350be51f0d713a7ee4ea5b5d4eea45af498287
#   Stored in directory: c:\users\adity\appdata\local\pip\cache\wheels\ff\55\fb\b27a466be754d2a06ffe0e37b248d844f090a63b51becea85d
# Successfully built kaggle
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import kaggle

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|██████████| 200k/200k [00:00<00:00, 218kB/s]
# 100%|██████████| 200k/200k [00:00<00:00, 217kB/s]
# License(s): CC0-1.0
# ...

# %%
import zipfile
zip_ref = zipfile.ZipFile('orders.csv.zip')
zip_ref.extractall()

# %%
zip_ref.close()

# %%
df = pd.read_csv('orders.csv')

# %%
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df.describe()
# Out:
#           Order Id   Postal Code    cost price    List Price     Quantity  \
# count  9994.000000   9994.000000   9994.000000   9994.000000  9994.000000
# mean   4997.500000  55190.379428    201.189714    229.756854     3.789574
# std    2885.163629  32063.693350    537.743203    623.245839     2.225110
# min       1.000000   1040.000000      0.000000      0.000000     1.000000
# 25%    2499.250000  23223.000000     20.000000     20.000000     2.000000
# 50%    4997.500000  56430.500000     50.000000     50.000000     3.000000
# 75%    7495.750000  90008.000000    180.000000    210.000000     5.000000
# max    9994.000000  99301.000000  18110.000000  22640.000000    14.000000
#
#        Discount Percent
# count       9994.000000
# mean           3.484090
# std            1.114211
# min            2.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %%
df.count()
# Out:
# Order Id            9994
# Order Date          9994
# Ship Mode           9993
# Segment             9994
# Country             9994
# City                9994
# State               9994
# Postal Code         9994
# Region              9994
# Category            9994
# Sub Category        9994
# Product Id          9994
# cost price          9994
# List Price          9994
# Quantity            9994
# Discount Percent    9994
# dtype: int64

# %%
df.head(20)
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13   Not Available     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23   Not Available     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31   Not Available     Consumer  United States
# 11        12  2023-12-25   Not Available     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %%
df['Ship Mode'] = df['Ship Mode'].replace({'Not Available': None , 'unknown': None })

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', None, 'First Class', nan,
#        'Same Day'], dtype=object)

# %%
df['Ship Mode'] = df['Ship Mode'].replace({None : "nan" })

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'nan', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.columns = df.columns.str.lower()

df.columns = df.columns.str.replace(' ','_')

df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent'],
#       dtype='object')

# %%
df['discount']= df['list_price']*df['discount_percent']*(0.01)

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent', 'discount'],
#       dtype='object')

# %%
df['sales_price'] = df['list_price'] - df['discount']

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent', 'discount', 'sales_price'],
#       dtype='object')

# %%
df['profit'] = df['sales_price'] - df['cost_price']

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent', 'discount', 'sales_price', 'profit'],
#       dtype='object')

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
df.dtypes
# Out:
# order_id              int64
# order_date           object
# ship_mode            object
# segment              object
# country              object
# city                 object
# state                object
# postal_code           int64
# region               object
# category             object
# sub_category         object
# product_id           object
# cost_price            int64
# list_price            int64
# quantity              int64
# discount_percent      int64
# discount            float64
# sales_price         float64
# profit              float64
# dtype: object

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df.dtypes
# Out:
# order_id                     int64
# order_date          datetime64[ns]
# ship_mode                   object
# segment                     object
# country                     object
# city                        object
# state                       object
# postal_code                  int64
# region                      object
# category                    object
# sub_category                object
# product_id                  object
# cost_price                   int64
# list_price                   int64
# quantity                     int64
# discount_percent             int64
# discount                   float64
# sales_price                float64
# profit                     float64
# dtype: object

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://root:Aznpsaznps@07@127.0.0.1:3306/Customers')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 engine = create_engine('mysql+mysqlconnector://root:Aznpsaznps@07@127.0.0.1:3306/Customers')
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\deprecations.py:309, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     302     if m in kwargs:
#     303         _warn_with_version(
#     304             messages[m],
#     305             versions[m],
#     306             version_warnings[m],
#     307             stacklevel=3,
#     308         )
# --> 309 return fn(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py:560, in create_engine(url, **kwargs)
#     558         if k in kwargs:
#     559             dbapi_args[k] = pop_kwarg(k)
# ...

# %%
# !pip install sqlalchemy pymysql
# Out:
# ...
#   Obtaining dependency information for pymysql from https://files.pythonhosted.org/packages/0c/94/e4181a1f6286f545507528c78016e00065ea913276888db2262507693ce5/PyMySQL-1.1.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    --------------------------- ------------ 30.7/45.0 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 45.0/45.0 kB 739.0 kB/s eta 0:00:00
# ...

# %%
from sqlalchemy import create_engine, text
import pandas as pd

# 1) Connect to MySQL server (no DB specified)
admin_engine = create_engine(
    'mysql+pymysql://root:Aznpsaznps%4007@127.0.0.1:3306/',
    echo=True  # optional: logs SQL
)

with admin_engine.begin() as conn:
    # 2) Create database if it doesn't exist
    conn.execute(text("CREATE DATABASE IF NOT EXISTS customer"))

# dispose the admin engine
admin_engine.dispose()
# Out:
# 2025-04-11 00:34:40,609 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-04-11 00:34:40,610 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-11 00:34:40,615 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-04-11 00:34:40,619 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-11 00:34:40,621 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-04-11 00:34:40,623 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-11 00:34:40,626 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-04-11 00:34:40,627 INFO sqlalchemy.engine.Engine CREATE DATABASE IF NOT EXISTS customer
# 2025-04-11 00:34:40,627 INFO sqlalchemy.engine.Engine [generated in 0.00072s] {}
# 2025-04-11 00:34:40,643 INFO sqlalchemy.engine.Engine COMMIT

# %%
engine = create_engine(
    'mysql+pymysql://root:Aznpsaznps%4007@127.0.0.1:3306/customer',
    echo=True
)
conn = engine.connect()
# Out:
# 2025-04-11 00:35:12,932 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-04-11 00:35:12,932 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-11 00:35:12,933 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-04-11 00:35:12,934 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-04-11 00:35:12,935 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-04-11 00:35:12,936 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
df.to_sql('df_orders', engine, if_exists='append', index=False)
# Out:
# 2025-04-11 00:52:14,289 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2025-04-11 00:52:14,290 INFO sqlalchemy.engine.Engine [cached since 998.3s ago] {'table_schema': 'customer', 'table_name': 'df_orders'}
# 2025-04-11 00:52:14,304 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-04-11 00:52:14,410 INFO sqlalchemy.engine.Engine INSERT INTO df_orders (order_id, order_date, ship_mode, segment, country, city, state, postal_code, region, category, sub_category, product_id, cost_price, list_price, quantity, discount_percent, discount, sales_price, profit) VALUES (%(order_id)s, %(order_date)s, %(ship_mode)s, %(segment)s, %(country)s, %(city)s, %(state)s, %(postal_code)s, %(region)s, %(category)s, %(sub_category)s, %(product_id)s, %(cost_price)s, %(list_price)s, %(quantity)s, %(discount_percent)s, %(discount)s, %(sales_price)s, %(profit)s)
# ...

# %%
df.describe()
# Out:
#           order_id   postal_code    cost_price    list_price     quantity  \
# count  9994.000000   9994.000000   9994.000000   9994.000000  9994.000000
# mean   4997.500000  55190.379428    201.189714    229.756854     3.789574
# std    2885.163629  32063.693350    537.743203    623.245839     2.225110
# min       1.000000   1040.000000      0.000000      0.000000     1.000000
# 25%    2499.250000  23223.000000     20.000000     20.000000     2.000000
# 50%    4997.500000  56430.500000     50.000000     50.000000     3.000000
# 75%    7495.750000  90008.000000    180.000000    210.000000     5.000000
# max    9994.000000  99301.000000  18110.000000  22640.000000    14.000000
#
#        discount_percent     discount   sales_price       profit
# count       9994.000000  9994.000000   9994.000000  9994.000000
# mean           3.484090     8.037953    221.718901    20.529188
# std            1.114211    22.978004    601.399604    72.514547
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          9994 non-null   int64
#  1   order_date        9994 non-null   datetime64[ns]
#  2   ship_mode         9994 non-null   object
#  3   segment           9994 non-null   object
#  4   country           9994 non-null   object
#  5   city              9994 non-null   object
#  6   state             9994 non-null   object
#  7   postal_code       9994 non-null   int64
#  8   region            9994 non-null   object
#  9   category          9994 non-null   object
#  10  sub_category      9994 non-null   object
#  11  product_id        9994 non-null   object
#  12  cost_price        9994 non-null   int64
#  13  list_price        9994 non-null   int64
#  14  quantity          9994 non-null   int64
#  15  discount_percent  9994 non-null   int64
# ...
